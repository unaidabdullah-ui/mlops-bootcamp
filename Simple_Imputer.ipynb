# %%
import numpy as np
from sklearn.impute import SimpleImputer

# %%
data = [[3,np.nan],[np.nan,5],[8,0]]

# %%
imputer = SimpleImputer(strategy='mean')

# %%
print(imputer.fit_transform(data))
# Out:
# [[3.  2.5]
#  [5.5 5. ]
#  [8.  0. ]]
